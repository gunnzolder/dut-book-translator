# %% [markdown]
# Prepare the 'env.txt' file by uploading a copy of your .env file, or make a new one with the below contents:
# ```yaml
#
# # Anthropic
# ANTHROPIC_API_KEY=<YOUR ANTHROPIC API KEY>
#
# # OpenAI
# OPENAI_API_KEY=<YOUR ANTHROPIC API KEY>
#
# ```

# %%
# %pip install python-dotenv -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
markdown_parser_system_prompt = '''

You're a helpful assistant for blind students helping to read the texts with formulas from images.

You read the text with formulas and mathematic symbols and convert it to markdown using LaTeX for them using syntax from examples below.

User will send you the scanned pages of a book one by one, and you would respond with the markdown code. 

1. Don't include the header with the chapter title and footnotes in the content.
2. Use markdown for titles, lists, tables, etc.
3. Don't add anything, just respond with the parsed text. 
4. For illustrations, insert [illustration, page N], N is the page number (top right for even or left for odd). Don't try to parse the text on illustrations.
5. Always use "$" notation for inline formulas, and "$$" for displayed formulas.
6. Don't add anything outside of the triple backticks.

Example of a LaTeX formula in Markdown:
```
Here is an inline formula: $E = mc^2$.

And here is a displayed formula:
$$
E = mc^2
$$

```

Example of markdown titles:
```
# Chapter 2
# Data Preparation

## 7.1 Introduction

### 7.2.1 Representative-Based Algorithms

#### 7.2.1.1 k-Modes Clustering
```
'''

# %%
# %pip install langchain_core langchain_openai -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
import os
import time
import concurrent.futures

# SETTINGS
model = "gpt-4o"
max_tokens = 4096
first_page = 429
last_page = 473
markdown_folder = './markdown'
multi_stream = True  # Enable multi-streaming
system_prompt = "Your system prompt here"


def process_page(image_url, markdown_folder, system_prompt=markdown_parser_system_prompt):
    base_name = os.path.basename(image_url)
    md_filename = os.path.splitext(base_name)[0] + '.md'
    file_path = os.path.join(markdown_folder, md_filename)

    def save_markdown(input_str, file_path):
        if input_str.startswith('```') and input_str.endswith('```'):
            content = input_str[3:-3]
        else:
            content = input_str
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(content)

    chat = ChatOpenAI(model=model, max_tokens=max_tokens)

    messages = [
        SystemMessage(content=system_prompt),
        HumanMessage(
            content=[
                {
                    "type": "image_url",
                    "image_url": {
                        "url": image_url
                    },
                },
                {"type": "text", "text": "Please read the text on the image."},
            ]
        )
    ]

    output = chat.invoke(messages)

    save_markdown(output.content, file_path)
    print(f'Saved Markdown to {file_path}')
    return f'Processed page {image_url}'


# List of image URLs to process
image_urls = [
    f'https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_{str(page).zfill(3)}.jpeg'
    for page in range(first_page, last_page + 1)
]

if multi_stream:
    # Multi-streaming with ThreadPoolExecutor
    with concurrent.futures.ThreadPoolExecutor() as executor:
        # Submit all tasks to the executor
        futures = [executor.submit(
            process_page, image_url, markdown_folder) for image_url in image_urls]

        # Wait for all tasks to complete and print results
        for future in concurrent.futures.as_completed(futures):
            print(future.result())
else:
    # Single stream processing
    for image_url in image_urls:
        result = process_page(image_url, markdown_folder)
        print(result)
        time.sleep(0.5)  # Wait 0.5 seconds
# Out:
# Saved Markdown to ./markdown/page_437.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_437.jpeg
# Saved Markdown to ./markdown/page_440.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_440.jpeg
# Saved Markdown to ./markdown/page_431.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_431.jpeg
# Saved Markdown to ./markdown/page_429.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_429.jpeg
# Saved Markdown to ./markdown/page_438.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_438.jpeg
# Saved Markdown to ./markdown/page_434.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_434.jpeg
# Saved Markdown to ./markdown/page_432.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_432.jpeg
# Saved Markdown to ./markdown/page_435.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_435.jpeg
# Saved Markdown to ./markdown/page_439.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_439.jpeg
# Saved Markdown to ./markdown/page_430.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_430.jpeg
# Saved Markdown to ./markdown/page_433.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_433.jpeg
# Saved Markdown to ./markdown/page_436.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_436.jpeg
# Saved Markdown to ./markdown/page_448.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_448.jpeg
# Saved Markdown to ./markdown/page_449.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_449.jpeg
# Saved Markdown to ./markdown/page_442.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_442.jpeg
# Saved Markdown to ./markdown/page_446.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_446.jpeg
# Saved Markdown to ./markdown/page_447.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_447.jpeg
# Saved Markdown to ./markdown/page_444.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_444.jpeg
# Saved Markdown to ./markdown/page_445.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_445.jpeg
# Saved Markdown to ./markdown/page_443.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_443.jpeg
# Saved Markdown to ./markdown/page_441.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_441.jpeg
# Saved Markdown to ./markdown/page_451.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_451.jpeg
# Saved Markdown to ./markdown/page_450.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_450.jpeg
# Saved Markdown to ./markdown/page_454.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_454.jpeg
# Saved Markdown to ./markdown/page_452.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_452.jpeg
# Saved Markdown to ./markdown/page_460.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_460.jpeg
# Saved Markdown to ./markdown/page_457.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_457.jpeg
# Saved Markdown to ./markdown/page_453.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_453.jpeg
# Saved Markdown to ./markdown/page_455.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_455.jpeg
# Saved Markdown to ./markdown/page_456.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_456.jpeg
# Saved Markdown to ./markdown/page_461.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_461.jpeg
# Saved Markdown to ./markdown/page_464.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_464.jpeg
# Saved Markdown to ./markdown/page_459.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_459.jpeg
# Saved Markdown to ./markdown/page_462.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_462.jpeg
# Saved Markdown to ./markdown/page_458.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_458.jpeg
# Saved Markdown to ./markdown/page_463.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_463.jpeg
# Saved Markdown to ./markdown/page_466.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_466.jpeg
# Saved Markdown to ./markdown/page_467.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_467.jpeg
# Saved Markdown to ./markdown/page_465.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_465.jpeg
# Saved Markdown to ./markdown/page_469.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_469.jpeg
# Saved Markdown to ./markdown/page_471.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_471.jpeg
# Saved Markdown to ./markdown/page_468.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_468.jpeg
# Saved Markdown to ./markdown/page_470.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_470.jpeg
# Saved Markdown to ./markdown/page_473.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_473.jpeg
# Saved Markdown to ./markdown/page_472.md
# Processed page https://translation-demo.s3.eu-central-1.amazonaws.com/images/page_472.jpeg

# %%
# %pip install -Uq langchain langchain_anthropic anthropic
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
translate_system_prompt = '''

You are a top-notch technical translator, specializing in translating scientific markdown files on COMPUTER SCIENCE. 

User will send you a file contents in English, and you will translate it to Ukrainian. For specific terms, refer to the dictionary below.

1. Keep the meaning as close as pssible to original, remember that it is a technical document for data science specialists.
2. You are NOT allowed to change the structure or formatting of the document.
3. You are NOT allowed to change the Latex formulas.
4. You respond in pure markdown format, without any additional content.
5. Don't add anything, just translate the text.
6. You allowed to use only common names for terms. If you don't find the term in the dictionary, keep it in English.
7. If there is a piece of code, leave it as it is, don't translate it.

<dictionary>
{dictionary}
</dictionary>

'''

dictionary = "\n".join([
    "bloom filter - фільтр Блума",
    "count–min sketch - скетч count–min"
])

# %%
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate
import os
import time
import concurrent.futures

model = 'claude-3-sonnet-20240229'
max_tokens = 4096
markdown_folder = './markdown'
output_folder = './markdown_ua'
first_page = 429
last_page = 473
multi_stream = True  # Enable multi-streaming
max_workers = 3  # Limit concurrent connections to 3
system_prompt = translate_system_prompt


def save_markdown(input_str, file_path):
    if input_str.startswith('```markdown'):
        content = input_str[len('```markdown'):].lstrip()
    elif input_str.startswith('```'):
        content = input_str[3:].lstrip()
    else:
        content = input_str

    if content.endswith('```'):
        content = content[:-3].rstrip()

    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(content)


def translate_file(file_name, output_folder, system_prompt=system_prompt):
    os.makedirs(output_folder, exist_ok=True)
    llm = ChatAnthropic(temperature=0, model_name=model, max_tokens=max_tokens)

    with open(file_name, 'r') as f:
        text = f.read()

    human_message = "{text}"
    prompt = ChatPromptTemplate.from_messages([
        ("system", system_prompt),
        ("human", human_message)
    ])
    chain = prompt | llm

    response = chain.invoke({"dictionary": dictionary, "text": text})

    base_name = os.path.splitext(os.path.basename(file_name))[0] + '_ua.md'
    file_path = os.path.join(output_folder, base_name)
    save_markdown(response.content, file_path)
    print(f'Saved translation to {file_path}')
    return f'Processed page {file_name}'


# List of file names to process
file_names = [
    f'{markdown_folder}/page_{str(page).zfill(3)}.md'
    for page in range(first_page, last_page + 1)
]

if multi_stream:
    # Multi-streaming with ThreadPoolExecutor, limiting to 3 concurrent connections
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks to the executor
        futures = [executor.submit(
            translate_file, file_name, output_folder, system_prompt) for file_name in file_names]

        # Wait for all tasks to complete and print results
        for future in concurrent.futures.as_completed(futures):
            print(future.result())
else:
    # Single stream processing
    for file_name in file_names:
        result = translate_file(file_name, output_folder, system_prompt)
        print(result)
        time.sleep(0.5)  # Wait 0.5 seconds
# Out:
# Saved translation to ./markdown_ua/page_430_ua.md
# Processed page ./markdown/page_430.md
# Saved translation to ./markdown_ua/page_429_ua.md
# Processed page ./markdown/page_429.md
# Saved translation to ./markdown_ua/page_431_ua.md
# Processed page ./markdown/page_431.md
# Saved translation to ./markdown_ua/page_434_ua.md
# Processed page ./markdown/page_434.md
# Saved translation to ./markdown_ua/page_433_ua.md
# Processed page ./markdown/page_433.md
# Saved translation to ./markdown_ua/page_432_ua.md
# Processed page ./markdown/page_432.md
# Saved translation to ./markdown_ua/page_437_ua.md
# Processed page ./markdown/page_437.md
# Saved translation to ./markdown_ua/page_436_ua.md
# Processed page ./markdown/page_436.md
# Saved translation to ./markdown_ua/page_438_ua.md
# Processed page ./markdown/page_438.md
# Saved translation to ./markdown_ua/page_440_ua.md
# Processed page ./markdown/page_440.md
# Saved translation to ./markdown_ua/page_435_ua.md
# Processed page ./markdown/page_435.md
# Saved translation to ./markdown_ua/page_439_ua.md
# Processed page ./markdown/page_439.md
# Saved translation to ./markdown_ua/page_442_ua.md
# Processed page ./markdown/page_442.md
# Saved translation to ./markdown_ua/page_441_ua.md
# Processed page ./markdown/page_441.md
# Saved translation to ./markdown_ua/page_444_ua.md
# Processed page ./markdown/page_444.md
# Saved translation to ./markdown_ua/page_445_ua.md
# Processed page ./markdown/page_445.md
# Saved translation to ./markdown_ua/page_443_ua.md
# Processed page ./markdown/page_443.md
# Saved translation to ./markdown_ua/page_447_ua.md
# Processed page ./markdown/page_447.md
# Saved translation to ./markdown_ua/page_448_ua.md
# Processed page ./markdown/page_448.md
# Saved translation to ./markdown_ua/page_446_ua.md
# Processed page ./markdown/page_446.md
# Saved translation to ./markdown_ua/page_449_ua.md
# Processed page ./markdown/page_449.md
# Saved translation to ./markdown_ua/page_451_ua.md
# Processed page ./markdown/page_451.md
# Saved translation to ./markdown_ua/page_450_ua.md
# Processed page ./markdown/page_450.md
# Saved translation to ./markdown_ua/page_452_ua.md
# Processed page ./markdown/page_452.md
# Saved translation to ./markdown_ua/page_454_ua.md
# Processed page ./markdown/page_454.md
# Saved translation to ./markdown_ua/page_453_ua.md
# Processed page ./markdown/page_453.md
# Saved translation to ./markdown_ua/page_455_ua.md
# Processed page ./markdown/page_455.md
# Saved translation to ./markdown_ua/page_456_ua.md
# Processed page ./markdown/page_456.md
# Saved translation to ./markdown_ua/page_457_ua.md
# Processed page ./markdown/page_457.md
# Saved translation to ./markdown_ua/page_458_ua.md
# Processed page ./markdown/page_458.md
# Saved translation to ./markdown_ua/page_460_ua.md
# Processed page ./markdown/page_460.md
# Saved translation to ./markdown_ua/page_459_ua.md
# Processed page ./markdown/page_459.md
# Saved translation to ./markdown_ua/page_461_ua.md
# Processed page ./markdown/page_461.md
# Saved translation to ./markdown_ua/page_464_ua.md
# Processed page ./markdown/page_464.md
# Saved translation to ./markdown_ua/page_462_ua.md
# Processed page ./markdown/page_462.md
# Saved translation to ./markdown_ua/page_463_ua.md
# Processed page ./markdown/page_463.md
# Saved translation to ./markdown_ua/page_465_ua.md
# Processed page ./markdown/page_465.md
# Saved translation to ./markdown_ua/page_466_ua.md
# Processed page ./markdown/page_466.md
# Saved translation to ./markdown_ua/page_467_ua.md
# Processed page ./markdown/page_467.md
# Saved translation to ./markdown_ua/page_469_ua.md
# Processed page ./markdown/page_469.md
# Saved translation to ./markdown_ua/page_468_ua.md
# Processed page ./markdown/page_468.md
# Saved translation to ./markdown_ua/page_470_ua.md
# Processed page ./markdown/page_470.md
# Saved translation to ./markdown_ua/page_471_ua.md
# Processed page ./markdown/page_471.md
# Saved translation to ./markdown_ua/page_472_ua.md
# Processed page ./markdown/page_472.md
# Saved translation to ./markdown_ua/page_473_ua.md
# Processed page ./markdown/page_473.md
